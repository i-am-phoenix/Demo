# %%
# import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read in redfin csv sample
redfin_sample=pd.read_csv("data/redfin/redfin_2021-05-26-17-55-16_77008.csv")
redfin_sample.dropnan()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-37c210ce7393> in <module>
#       1 # Read in redfin csv sample
#       2 redfin_sample=pd.read_csv("data/redfin/redfin_2021-05-26-17-55-16_77008.csv")
# ----> 3 redfin_sample.dropnan()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dropnan'

# %%
# filter only SOLD data
redfin_sold=redfin_sample[redfin_sample['SALE TYPE']=="PAST SALE"]
redfin_sold
# Out:
#      SALE TYPE          SOLD DATE              PROPERTY TYPE  \
# 2    PAST SALE      August-5-2019  Single Family Residential
# 3    PAST SALE  September-12-2019  Single Family Residential
# 4    PAST SALE     October-4-2018  Single Family Residential
# 5    PAST SALE     January-5-2021  Single Family Residential
# 6    PAST SALE       June-17-2019  Single Family Residential
# ..         ...                ...                        ...
# 345  PAST SALE         May-7-2021  Single Family Residential
# 346  PAST SALE    October-12-2018  Single Family Residential
# 347  PAST SALE       March-9-2018  Single Family Residential
# 348  PAST SALE     October-9-2020  Single Family Residential
# 349  PAST SALE                NaN                Condo/Co-op
#
#                       ADDRESS     CITY STATE OR PROVINCE  ZIP OR POSTAL CODE  \
# 2               335 W 26th St  Houston                TX               77008
# 3         810 T C Jester Blvd  Houston                TX               77008
# 4               237 W 22nd St  Houston                TX               77008
# 5             1131 Allston St  Houston                TX               77008
# 6             1347 Beverly St  Houston                TX               77008
# ..                        ...      ...               ...                 ...
# 345            713 E 13th Sts  Houston                TX               77008
# 346            1129 W 26th St  Houston                TX               77008
# 347     1009 Green Kensington  Houston                TX               77008
# 348             715 E 13th St  Houston                TX               77008
# 349  1402 West 26th St Unit C  Houston                TX               77008
#
#          PRICE  BEDS  BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  \
# 2     385000.0   3.0    2.5  ...   Sold                         NaN
# 3     439000.0   2.0    2.0  ...   Sold                         NaN
# 4     455000.0   2.0    1.0  ...   Sold                         NaN
# 5     639000.0   2.0    1.0  ...   Sold                         NaN
# 6     325000.0   3.0    1.0  ...   Sold                         NaN
# ..         ...   ...    ...  ...    ...                         ...
# 345  1549000.0   4.0    5.0  ...   Sold                         NaN
# 346   433750.0   3.0    2.5  ...   Sold                         NaN
# 347   317900.0   3.0    2.5  ...   Sold                         NaN
# 348   799000.0   3.0    3.0  ...   Sold                         NaN
# 349        NaN   3.0    3.5  ...   Sold                         NaN
#
#      NEXT OPEN HOUSE END TIME  \
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# ..                        ...
# 345                       NaN
# 346                       NaN
# 347                       NaN
# 348                       NaN
# 349                       NaN
#
#      URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 2    http://www.redfin.com/TX/Houston/335-W-26th-St...
# 3    http://www.redfin.com/TX/Houston/810-T-C-Jeste...
# 4    http://www.redfin.com/TX/Houston/237-W-22nd-St...
# 5    http://www.redfin.com/TX/Houston/1131-Allston-...
# 6    http://www.redfin.com/TX/Houston/1347-Beverly-...
# ..                                                 ...
# 345  http://www.redfin.com/TX/Houston/713-E-13th-St...
# 346  http://www.redfin.com/TX/Houston/1129-W-26th-S...
# 347  http://www.redfin.com/TX/Houston/1009-Green-Ke...
# 348  http://www.redfin.com/TX/Houston/715-E-13th-St...
# 349  http://www.redfin.com/TX/Houston/1402-W-26th-S...
#
#      SOURCE      MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 2    HARMLS  75102551         N          Y  29.810235 -95.402974
# 3    HARMLS  89059252         N          Y  29.787504 -95.416394
# 4    HARMLS  48320575         N          Y  29.806212 -95.401011
# 5    HARMLS  72471567         N          Y  29.791777 -95.400367
# 6    HARMLS  79396930         N          Y  29.796053 -95.390295
# ..      ...       ...       ...        ...        ...        ...
# 345  HARMLS  25367501         N          Y  29.794777 -95.389062
# 346  HARMLS  42686263         N          Y  29.810024 -95.419176
# 347  HARMLS  36018402         N          Y  29.788018 -95.438285
# 348  HARMLS  85168197         N          Y  29.794756 -95.388945
# 349  HARMLS       NaN         N          Y  29.809595 -95.424300
#
# [121 rows x 27 columns]

# %%
redfin_sold_group_by_type=redfin_sold.groupby('PROPERTY TYPE')
redfin_sold_group_by_type.describe()
# Out:
#                           ZIP OR POSTAL CODE                                  \
#                                        count     mean  std      min      25%
# PROPERTY TYPE
# Condo/Co-op                              1.0  77008.0  NaN  77008.0  77008.0
# Single Family Residential              107.0  77008.0  0.0  77008.0  77008.0
# Townhouse                               11.0  77008.0  0.0  77008.0  77008.0
# Vacant Land                              2.0  77008.0  0.0  77008.0  77008.0
#
#                                                       PRICE                 \
#                                50%      75%      max  count           mean
# PROPERTY TYPE
# Condo/Co-op                77008.0  77008.0  77008.0    0.0            NaN
# Single Family Residential  77008.0  77008.0  77008.0  105.0  546060.209524
# Townhouse                  77008.0  77008.0  77008.0   11.0  365672.545455
# Vacant Land                77008.0  77008.0  77008.0    2.0  464500.000000
#
#                            ...   LATITUDE            LONGITUDE             \
#                            ...        75%        max     count       mean
# PROPERTY TYPE              ...
# Condo/Co-op                ...  29.809595  29.809595       1.0 -95.424300
# Single Family Residential  ...  29.806889  29.811776     107.0 -95.416220
# Townhouse                  ...  29.805286  29.808145      11.0 -95.422150
# Vacant Land                ...  29.790232  29.791457       2.0 -95.418255
#
#                                                                       \
#                                 std        min        25%        50%
# PROPERTY TYPE
# Condo/Co-op                     NaN -95.424300 -95.424300 -95.424300
# Single Family Residential  0.013400 -95.445796 -95.423708 -95.417703
# Townhouse                  0.011331 -95.432126 -95.431283 -95.421795
# Vacant Land                0.003675 -95.420854 -95.419555 -95.418255
#
#
#                                  75%        max
# PROPERTY TYPE
# Condo/Co-op               -95.424300 -95.424300
# Single Family Residential -95.408001 -95.388945
# Townhouse                 -95.420200 -95.399270
# Vacant Land               -95.416956 -95.415657
#
# [4 rows x 96 columns]
